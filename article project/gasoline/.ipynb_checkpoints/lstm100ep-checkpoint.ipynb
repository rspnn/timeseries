# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline

from matplotlib.pylab import rcParams
rcParams['figure.figsize'] =20,10

from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0,1))

#df = pd.read_csv('Diesel.csv')
df = pd.read_csv('Gasoline.csv')
df
# Out:
#          Tanggal    qty       Jumlah
# 0     2016-01-01   8694   63467076.0
# 1     2016-01-02  10044   73320032.0
# 2     2016-01-03  13928  101671188.0
# 3     2016-01-04  12518   91382972.0
# 4     2016-01-05  11112   77424375.0
# ...          ...    ...          ...
# 1993  2021-10-25  12239   93628350.0
# 1994  2021-10-26  11319   86590350.0
# 1995  2021-10-27  12502   95640300.0
# 1996  2021-10-28  12456   95288400.0
# 1997  2021-10-29  11228   85894200.0
#
# [1998 rows x 3 columns]

# %%
# Mengatur Tanggal dan Data
df['Tanggal'] = pd.to_datetime(df.Tanggal, format='%Y-%m-%d')
df.index = df['Tanggal']

#Plot
plt.figure(figsize=(20,10))
plt.plot(df['Jumlah'],label='History Harga Penutup')
plt.title('Diesel', fontsize=18)
plt.ylabel('Total',fontsize=18)
plt.xlabel('Date',fontsize=18)
# Out:
# Text(0.5, 0, 'Date')

# %%
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense,Dropout,LSTM

#Membuat Matrix 2 Dimensi
data = df.sort_index(ascending=True,axis=0)
new_data = pd.DataFrame(index=range(0,len(df)),columns=['Tanggal','Jumlah'])
for i in range(0,len(df)):
    new_data['Tanggal'][i] = data['Tanggal'][i]
    new_data['Jumlah'][i] = data['Jumlah'][i]
    
#Membuat Tanggal menjadi Index di variable new_data
new_data.index = new_data['Tanggal']
new_data.drop('Tanggal',axis=1,inplace=True)

#Membuat Data Latih dan Test
#Menampung Data Untuk dijadikan Data olah
dataset = new_data.values 
#Membuat data latih
train = dataset[0:1670,:]
#Membuat Data Uji
valid = dataset[1670:,:]
# Out:
# 2023-12-18 16:08:45.242000: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-12-18 16:08:45.291436: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-18 16:08:45.291488: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-18 16:08:45.291514: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-18 16:08:45.299427: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-12-18 16:08:45.300015: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-12-18 16:08:46.290628: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /tmp/ipykernel_101251/724515476.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   new_data['Tanggal'][i] = data['Tanggal'][i]
# /tmp/ipykernel_101251/724515476.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   new_data['Jumlah'][i] = data['Jumlah'][i]

# %%
#Normalisasi Data 
scaler = MinMaxScaler(feature_range=(0,1))
scaled_data = scaler.fit_transform(dataset)

x_train,y_train = [],[]
for i in range(60,len(train)):
    x_train.append(scaled_data[i-60:i,0])
    y_train.append(scaled_data[i,0])
x_train,y_train = np.array(x_train),np.array(y_train)

x_train = np.reshape(x_train,(x_train.shape[0],x_train.shape[1],1))

print(x_train)
# Out:
# [[[0.35237041]
#   [0.40708254]
#   [0.56451266]
#   ...
#   [0.41636229]
#   [0.00106129]
#   [0.36089651]]
#
#  [[0.40708254]
#   [0.56451266]
#   [0.5073836 ]
#   ...
#   [0.00106129]
#   [0.36089651]
#   [0.45212047]]
#
#  [[0.56451266]
#   [0.5073836 ]
#   [0.4298734 ]
#   ...
#   [0.36089651]
#   [0.45212047]
#   [0.39878692]]
#
#  ...
#
#  [[0.72081448]
#   [0.62518582]
#   [0.56848914]
#   ...
#   [0.56752211]
#   [0.5688473 ]
#   [0.28518478]]
#
#  [[0.62518582]
#   [0.56848914]
#   [0.56322419]
#   ...
#   [0.5688473 ]
#   [0.28518478]
#   [0.5693129 ]]
#
#  [[0.56848914]
#   [0.56322419]
#   [0.56716395]
#   ...
#   [0.28518478]
#   [0.5693129 ]
#   [0.28174644]]]

# %%
# Membuat Model dan fit LSTM Network
import time
mulai = time.time()

model = Sequential()
model.add(LSTM(units=60,return_sequences=True,input_shape=(x_train.shape[1],1)))
model.add(LSTM(units=60))
model.add(Dropout(0.3))
model.add(Dense(1))

model.compile(loss='mean_squared_error',optimizer='adam')
model.fit(x_train,y_train,epochs=100,batch_size=4,verbose=1,validation_data=(x_train, y_train))
# Out:
# Epoch 1/100
# 403/403 [==============================] - 18s 38ms/step - loss: 0.0172 - val_loss: 0.0124
# Epoch 2/100
# 403/403 [==============================] - 15s 38ms/step - loss: 0.0141 - val_loss: 0.0158
# Epoch 3/100
# 403/403 [==============================] - 15s 37ms/step - loss: 0.0139 - val_loss: 0.0112
# Epoch 4/100
# 403/403 [==============================] - 15s 38ms/step - loss: 0.0135 - val_loss: 0.0109
# Epoch 5/100
# 403/403 [==============================] - 15s 38ms/step - loss: 0.0137 - val_loss: 0.0137
# Epoch 6/100
# 403/403 [==============================] - 15s 37ms/step - loss: 0.0129 - val_loss: 0.0108
# Epoch 7/100
# 403/403 [==============================] - 15s 38ms/step - loss: 0.0131 - val_loss: 0.0113
# Epoch 8/100
# 403/403 [==============================] - 14s 35ms/step - loss: 0.0129 - val_loss: 0.0116
# Epoch 9/100
# 403/403 [==============================] - 12s 29ms/step - loss: 0.0126 - val_loss: 0.0111
# Epoch 10/100
# 403/403 [==============================] - 12s 30ms/step - loss: 0.0124 - val_loss: 0.0109
# Epoch 11/100
# 403/403 [==============================] - 12s 30ms/step - loss: 0.0123 - val_loss: 0.0130
# Epoch 12/100
# 403/403 [==============================] - 12s 31ms/step - loss: 0.0127 - val_loss: 0.0120
# Epoch 13/100
# 403/403 [==============================] - 14s 34ms/step - loss: 0.0121 - val_loss: 0.0110
# Epoch 14/100
# 403/403 [==============================] - 13s 32ms/step - loss: 0.0124 - val_loss: 0.0115
# Epoch 15/100
# 403/403 [==============================] - 19s 47ms/step - loss: 0.0120 - val_loss: 0.0109
# Epoch 16/100
# 403/403 [==============================] - 13s 31ms/step - loss: 0.0118 - val_loss: 0.0111
# Epoch 17/100
# 403/403 [==============================] - 12s 31ms/step - loss: 0.0122 - val_loss: 0.0110
# Epoch 18/100
# 403/403 [==============================] - 13s 33ms/step - loss: 0.0119 - val_loss: 0.0108
# Epoch 19/100
# 403/403 [==============================] - 19s 47ms/step - loss: 0.0117 - val_loss: 0.0116
# Epoch 20/100
# 403/403 [==============================] - 13s 32ms/step - loss: 0.0120 - val_loss: 0.0110
# Epoch 21/100
# 403/403 [==============================] - 13s 32ms/step - loss: 0.0119 - val_loss: 0.0108
# Epoch 22/100
# 403/403 [==============================] - 13s 33ms/step - loss: 0.0116 - val_loss: 0.0152
# Epoch 23/100
# 403/403 [==============================] - 21s 52ms/step - loss: 0.0118 - val_loss: 0.0109
# Epoch 24/100
# 403/403 [==============================] - 16s 39ms/step - loss: 0.0119 - val_loss: 0.0107
# Epoch 25/100
# 403/403 [==============================] - 13s 32ms/step - loss: 0.0117 - val_loss: 0.0112
# Epoch 26/100
# 403/403 [==============================] - 19s 47ms/step - loss: 0.0118 - val_loss: 0.0109
# Epoch 27/100
# 403/403 [==============================] - 18s 45ms/step - loss: 0.0113 - val_loss: 0.0108
# Epoch 28/100
# 403/403 [==============================] - 15s 38ms/step - loss: 0.0112 - val_loss: 0.0106
# Epoch 29/100
# 403/403 [==============================] - 16s 40ms/step - loss: 0.0115 - val_loss: 0.0108
# Epoch 30/100
# 403/403 [==============================] - 12s 30ms/step - loss: 0.0115 - val_loss: 0.0106
# Epoch 31/100
# 403/403 [==============================] - 11s 28ms/step - loss: 0.0111 - val_loss: 0.0119
# Epoch 32/100
# 403/403 [==============================] - 13s 31ms/step - loss: 0.0115 - val_loss: 0.0110
# Epoch 33/100
# 403/403 [==============================] - 13s 32ms/step - loss: 0.0113 - val_loss: 0.0108
# Epoch 34/100
# 403/403 [==============================] - 13s 32ms/step - loss: 0.0112 - val_loss: 0.0108
# Epoch 35/100
# 403/403 [==============================] - 13s 32ms/step - loss: 0.0116 - val_loss: 0.0105
# Epoch 36/100
# 403/403 [==============================] - 13s 32ms/step - loss: 0.0113 - val_loss: 0.0110
# Epoch 37/100
# 403/403 [==============================] - 13s 31ms/step - loss: 0.0112 - val_loss: 0.0106
# Epoch 38/100
# 403/403 [==============================] - 13s 32ms/step - loss: 0.0110 - val_loss: 0.0108
# Epoch 39/100
# 403/403 [==============================] - 13s 32ms/step - loss: 0.0112 - val_loss: 0.0107
# Epoch 40/100
# 403/403 [==============================] - 13s 32ms/step - loss: 0.0114 - val_loss: 0.0107
# Epoch 41/100
# 403/403 [==============================] - 18s 44ms/step - loss: 0.0113 - val_loss: 0.0107
# Epoch 42/100
# 403/403 [==============================] - 13s 32ms/step - loss: 0.0111 - val_loss: 0.0107
# Epoch 43/100
# 403/403 [==============================] - 13s 31ms/step - loss: 0.0111 - val_loss: 0.0105
# Epoch 44/100
# 403/403 [==============================] - 13s 32ms/step - loss: 0.0114 - val_loss: 0.0123
# Epoch 45/100
# 403/403 [==============================] - 15s 38ms/step - loss: 0.0111 - val_loss: 0.0105
# Epoch 46/100
# 403/403 [==============================] - 14s 36ms/step - loss: 0.0111 - val_loss: 0.0104
# Epoch 47/100
# 403/403 [==============================] - 13s 31ms/step - loss: 0.0113 - val_loss: 0.0104
# Epoch 48/100
# 403/403 [==============================] - 12s 31ms/step - loss: 0.0112 - val_loss: 0.0104
# Epoch 49/100
# 403/403 [==============================] - 13s 31ms/step - loss: 0.0111 - val_loss: 0.0126
# Epoch 50/100
# 403/403 [==============================] - 12s 31ms/step - loss: 0.0112 - val_loss: 0.0112
# Epoch 51/100
# 403/403 [==============================] - 12s 31ms/step - loss: 0.0111 - val_loss: 0.0104
# Epoch 52/100
# 403/403 [==============================] - 12s 31ms/step - loss: 0.0111 - val_loss: 0.0105
# Epoch 53/100
# 403/403 [==============================] - 12s 31ms/step - loss: 0.0111 - val_loss: 0.0107
# Epoch 54/100
# 403/403 [==============================] - 13s 31ms/step - loss: 0.0109 - val_loss: 0.0102
# Epoch 55/100
# 403/403 [==============================] - 13s 31ms/step - loss: 0.0109 - val_loss: 0.0103
# Epoch 56/100
# 403/403 [==============================] - 13s 31ms/step - loss: 0.0109 - val_loss: 0.0104
# Epoch 57/100
# 403/403 [==============================] - 13s 31ms/step - loss: 0.0108 - val_loss: 0.0111
# Epoch 58/100
# 403/403 [==============================] - 13s 31ms/step - loss: 0.0110 - val_loss: 0.0102
# Epoch 59/100
# 403/403 [==============================] - 13s 31ms/step - loss: 0.0108 - val_loss: 0.0104
# Epoch 60/100
# 403/403 [==============================] - 13s 31ms/step - loss: 0.0109 - val_loss: 0.0103
# Epoch 61/100
# 403/403 [==============================] - 13s 32ms/step - loss: 0.0108 - val_loss: 0.0101
# Epoch 62/100
# 403/403 [==============================] - 13s 32ms/step - loss: 0.0108 - val_loss: 0.0100
# Epoch 63/100
# 403/403 [==============================] - 18s 45ms/step - loss: 0.0109 - val_loss: 0.0099
# Epoch 64/100
# 403/403 [==============================] - 13s 31ms/step - loss: 0.0108 - val_loss: 0.0102
# Epoch 65/100
# 403/403 [==============================] - 13s 31ms/step - loss: 0.0108 - val_loss: 0.0099
# Epoch 66/100
# 403/403 [==============================] - 13s 31ms/step - loss: 0.0107 - val_loss: 0.0101
# Epoch 67/100
# 403/403 [==============================] - 13s 31ms/step - loss: 0.0106 - val_loss: 0.0102
# Epoch 68/100
# 403/403 [==============================] - 13s 31ms/step - loss: 0.0105 - val_loss: 0.0100
# Epoch 69/100
# 403/403 [==============================] - 13s 32ms/step - loss: 0.0105 - val_loss: 0.0104
# Epoch 70/100
# 403/403 [==============================] - 13s 32ms/step - loss: 0.0105 - val_loss: 0.0099
# Epoch 71/100
# 403/403 [==============================] - 13s 32ms/step - loss: 0.0103 - val_loss: 0.0101
# Epoch 72/100
# 403/403 [==============================] - 13s 31ms/step - loss: 0.0103 - val_loss: 0.0099
# Epoch 73/100
# 403/403 [==============================] - 13s 32ms/step - loss: 0.0106 - val_loss: 0.0106
# Epoch 74/100
# 403/403 [==============================] - 13s 32ms/step - loss: 0.0105 - val_loss: 0.0105
# Epoch 75/100
# 403/403 [==============================] - 13s 32ms/step - loss: 0.0104 - val_loss: 0.0101
# Epoch 76/100
# 403/403 [==============================] - 13s 32ms/step - loss: 0.0102 - val_loss: 0.0100
# Epoch 77/100
# 403/403 [==============================] - 13s 32ms/step - loss: 0.0105 - val_loss: 0.0099
# Epoch 78/100
# 403/403 [==============================] - 13s 31ms/step - loss: 0.0105 - val_loss: 0.0103
# Epoch 79/100
# 403/403 [==============================] - 13s 32ms/step - loss: 0.0103 - val_loss: 0.0103
# Epoch 80/100
# 403/403 [==============================] - 13s 32ms/step - loss: 0.0103 - val_loss: 0.0103
# Epoch 81/100
# 403/403 [==============================] - 13s 31ms/step - loss: 0.0104 - val_loss: 0.0096
# Epoch 82/100
# 403/403 [==============================] - 17s 43ms/step - loss: 0.0102 - val_loss: 0.0096
# Epoch 83/100
# 403/403 [==============================] - 15s 37ms/step - loss: 0.0102 - val_loss: 0.0102
# Epoch 84/100
# 403/403 [==============================] - 15s 37ms/step - loss: 0.0103 - val_loss: 0.0097
# Epoch 85/100
# 403/403 [==============================] - 12s 31ms/step - loss: 0.0102 - val_loss: 0.0096
# Epoch 86/100
# 403/403 [==============================] - 13s 31ms/step - loss: 0.0102 - val_loss: 0.0096
# Epoch 87/100
# 403/403 [==============================] - 13s 31ms/step - loss: 0.0101 - val_loss: 0.0096
# Epoch 88/100
# 403/403 [==============================] - 13s 31ms/step - loss: 0.0102 - val_loss: 0.0096
# Epoch 89/100
# 403/403 [==============================] - 13s 32ms/step - loss: 0.0101 - val_loss: 0.0093
# Epoch 90/100
# 403/403 [==============================] - 15s 38ms/step - loss: 0.0101 - val_loss: 0.0093
# Epoch 91/100
# 403/403 [==============================] - 15s 38ms/step - loss: 0.0100 - val_loss: 0.0098
# Epoch 92/100
# 403/403 [==============================] - 13s 31ms/step - loss: 0.0101 - val_loss: 0.0092
# Epoch 93/100
# 403/403 [==============================] - 13s 32ms/step - loss: 0.0100 - val_loss: 0.0091
# Epoch 94/100
# 403/403 [==============================] - 12s 31ms/step - loss: 0.0099 - val_loss: 0.0092
# Epoch 95/100
# 403/403 [==============================] - 13s 32ms/step - loss: 0.0100 - val_loss: 0.0094
# Epoch 96/100
# 403/403 [==============================] - 13s 31ms/step - loss: 0.0099 - val_loss: 0.0095
# Epoch 97/100
# 403/403 [==============================] - 13s 32ms/step - loss: 0.0098 - val_loss: 0.0091
# Epoch 98/100
# 403/403 [==============================] - 15s 38ms/step - loss: 0.0098 - val_loss: 0.0095
# Epoch 99/100
# 403/403 [==============================] - 15s 37ms/step - loss: 0.0098 - val_loss: 0.0094
# Epoch 100/100
# 403/403 [==============================] - 12s 31ms/step - loss: 0.0097 - val_loss: 0.0092

# %%
#Prediksi 246 Values dengan 60 Data Train
inputs = new_data[len(new_data)-len(valid)-60:].values
inputs = inputs.reshape(-1,1)
inputs = scaler.transform(inputs)
x_test = []
for i in range(60,inputs.shape[0]):
    x_test.append(inputs[i-60:i,0])
x_test = np.array(x_test)
x_test = np.reshape(x_test,(x_test.shape[0],x_test.shape[1],1))

closing_price = model.predict(x_test)
closing_price = scaler.inverse_transform(closing_price)
# Out:
# 11/11 [==============================] - 1s 12ms/step

# %%
rmse = np.sqrt(np.mean((valid - closing_price)**2))
mape = np.mean(np.abs((valid - closing_price) / valid)) * 100

# %%
#Chart Grafik
train = new_data[:1670]
valid = new_data[1670:]

valid['Predictions'] = closing_price
plt.title('Long Short-Term Memory',fontsize=18)
plt.plot(train['Jumlah'])
plt.plot(valid['Jumlah'])
plt.plot(valid['Predictions'])

plt.plot(train['Jumlah'], label = 'Train Closing Price',color='blue')
plt.plot(valid['Jumlah'], label = 'Test Closing Price',color='orange')
plt.plot(valid['Predictions'], label = 'Predictions')
plt.legend(loc="upper left")
plt.xlabel('Date', fontsize=18)
plt.ylabel('Total', fontsize=18)
# plt.plot(df['Jumlah'],alpha = 0.5, label='Jumlah')
# plt.plot(df['SMA20'],alpha = 0.5, label='SMA20')
# plt.plot(df['SMA50'],alpha = 0.5, label='SMA50')
akhir = time.time()
waktu_detik = akhir - mulai
waktu_menit = "{:.2f}".format(waktu_detik / 60)

print("RMSE :","{:.2f}".format(rmse))
print("MAPE :","{:.2f}".format(mape),"%")


print(f"Program run in = {waktu_menit} min")
# Out:
# /tmp/ipykernel_101251/2080093279.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid['Predictions'] = closing_price
# RMSE : 12644631.85
# MAPE : 17.68 %
# Program run in = 33.89 min

# %%
plt.plot(valid['Jumlah'], label = 'Test Closing Price',color='orange')
plt.plot(valid['Predictions'], label = 'Predictions')
plt.legend(loc="upper left")
plt.xlabel('Date', fontsize=18)
plt.ylabel('Total', fontsize=18)
# Out:
# Text(0, 0.5, 'Total')
